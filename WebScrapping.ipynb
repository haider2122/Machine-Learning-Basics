# %%
from bs4 import BeautifulSoup

# %%
with open('webscrapping_practise.html','r') as code:
    print(code.read())
# Out:
# <!doctype html>
# <html lang="en">
#    <head>
#       <meta charset="utf-8">
#       <meta name="viewport" content="width=device-width, initial-scale=1, shrink-to-fit=no">
#       <link rel="stylesheet" href="https://stackpath.bootstrapcdn.com/bootstrap/4.5.2/css/bootstrap.min.css" integrity="sha384-JcKb8q3iqJ61gNV9KGb8thSsNjpSL0n8PARn9HuZOnIxN0hoP+VmmDGMN5t9UJ0Z" crossorigin="anonymous">
#       <title>My Courses</title>
#    </head>
#    <body>
#       <h1>Hello, Start Learning!</h1>
#       <div class="card" id="card-python-for-beginners">
#          <div class="card-header">
#             Python
#          </div>
#          <div class="card-body">
#             <h5 class="card-title">Python for beginners</h5>
#             <p class="card-text">If you are new to Python, this is the course that you should buy!</p>
#             <a href="#" class="btn btn-primary">Start for 20$</a>
#          </div>
#       </div>
#       <div class="card" id="card-python-web-development">
# ...

# %%
with open('webscrapping_practise.html','r') as code:
    file_code=code.read()
    soup=BeautifulSoup(file_code,'lxml')
    print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1, shrink-to-fit=no" name="viewport"/>
#   <link crossorigin="anonymous" href="https://stackpath.bootstrapcdn.com/bootstrap/4.5.2/css/bootstrap.min.css" integrity="sha384-JcKb8q3iqJ61gNV9KGb8thSsNjpSL0n8PARn9HuZOnIxN0hoP+VmmDGMN5t9UJ0Z" rel="stylesheet"/>
#   <title>
#    My Courses
#   </title>
#  </head>
#  <body>
#   <h1>
#    Hello, Start Learning!
#   </h1>
#   <div class="card" id="card-python-for-beginners">
#    <div class="card-header">
#     Python
#    </div>
#    <div class="card-body">
#     <h5 class="card-title">
#      Python for beginners
#     </h5>
#     <p class="card-text">
#      If you are new to Python, this is the course that you should buy!
#     </p>
#     <a class="btn btn-primary" href="#">
#      Start for 20$
#     </a>
#    </div>
#   </div>
#   <div class="card" id="card-python-web-development">
#    <div class="card-header">
# ...

# %%
print(soup.find('h5'))
print(soup.find_all('h5'))
# Out:
# <h5 class="card-title">Python for beginners</h5>
# [<h5 class="card-title">Python for beginners</h5>, <h5 class="card-title">Python Web Development</h5>, <h5 class="card-title">Python Machine Learning</h5>]

# %%
[x.text for x in soup.find_all('h5')]
# Out:
# ['Python for beginners', 'Python Web Development', 'Python Machine Learning']

# %%
for i in soup.find_all('div',class_='card'):#class is an inbuilt keyword, hence we add an 
    print(i.h5.text,end=': ')
    print('Price of Course'+i.a.text.split()[-1])
    print('_____________________________________________________________________________________')
# Out:
# Python for beginners: Price of Course20$
# _____________________________________________________________________________________
# Python Web Development: Price of Course50$
# _____________________________________________________________________________________
# Python Machine Learning: Price of Course100$
# _____________________________________________________________________________________

# %%
##Scrapiing from Live website
import requests

# %%
html_text=requests.get('https://www.screener.in/company/WIPRO/consolidated/#top').text
html_text
# Out:
# '\n<!DOCTYPE html>\n<html lang="en">\n\n<head>\n  <!-- Basic Page Needs -->\n  <meta charset="utf-8">\n  <title>Wipro Ltd financial results and price chart - Screener</title>\n  <meta name="author" content="Mittal Analytics Private Limited">\n\n  <!-- PWA manifest -->\n  <link rel="manifest" href="/static/manifest.d083a30d906d.webmanifest">\n  \n  <!-- Mobile Specific Meta -->\n  <meta name="viewport" content="width=device-width, initial-scale=1">\n\n  <!-- Google Tag Manager -->\n  <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({\'gtm.start\':\n  new Date().getTime(),event:\'gtm.js\'});var f=d.getElementsByTagName(s)[0],\n  j=d.createElement(s),dl=l!=\'dataLayer\'?\'&l=\'+l:\'\';j.async=true;j.src=\n  \'https://www.googletagmanager.com/gtm.js?id=\'+i+dl;f.parentNode.insertBefore(j,f);\n  })(window,document,\'script\',\'dataLayer\',\'GTM-KG8ZGC4\');</script>\n  <!-- End Google Tag Manager -->\n\n  <!-- FONT -->\n  <link href="https://rsms.me/inter/inter.css" rel="stylesheet">\n
# ...

# %%
soup=BeautifulSoup(html_text,'html')

# %%
soup.find('li',class_='flex flex-space-between').span.text.strip('\n ')
# Out:
# 'Market Cap'

# %%
[x.span.text.strip('\n ') for x in soup.find_all('li',class_='flex flex-space-between')]
# Out:
# ['Market Cap',
#  'Current Price',
#  'High / Low',
#  'Stock P/E',
#  'Book Value',
#  'Dividend Yield',
#  'ROCE',
#  'ROE',
#  'Face Value']

# %%
for i in soup.find_all('li',class_='flex flex-space-between'):
    print(i.span.text.strip('\n '),end=': ------')
    print((i.find('span',class_='nowrap value')).find('span',class_='number').text)
# Out:
# Market Cap: ------278,481
# Current Price: ------508
# High / Low: ------528
# Stock P/E: ------25.8
# Book Value: ------100
# Dividend Yield: ------0.20
# ROCE: ------22.5
# ROE: ------19.6
# Face Value: ------2.00

# %%
((soup.find('li',class_='flex flex-space-between')).find('span',class_='nowrap value')).find('span',class_='number').text
# Out:
# '278,481'

# %%
requests.get('https://www.screener.in/company/WIPRO/consolidated/#top')

# %%
##Google Search

# %%
text='screener.in + Wipro'
search_results=requests.get('https://google.com/search?q='+text).text
soup=BeautifulSoup(search_results,'lxml')
soup.prettify()
# Out:
# '<!DOCTYPE html>\n<html lang="en-IN">\n <head>\n  <meta charset="utf-8"/>\n  <meta content="/images/branding/googleg/1x/googleg_standard_color_128dp.png" itemprop="image"/>\n  <title>\n   screener.in   Wipro - Google Search\n  </title>\n  <script nonce="yI6s/Ixe+a1eUF1YklZbpw==">\n   (function(){\ndocument.documentElement.addEventListener("submit",function(b){var a;if(a=b.target){var c=a.getAttribute("data-submitfalse");a="1"==c||"q"==c&&!a.elements.q.value?!0:!1}else a=!1;a&&(b.preventDefault(),b.stopPropagation())},!0);document.documentElement.addEventListener("click",function(b){var a;a:{for(a=b.target;a&&a!=document.documentElement;a=a.parentElement)if("A"==a.tagName){a="1"==a.getAttribute("data-nohref");break a}a=!1}a&&b.preventDefault()},!0);}).call(this);(function(){\nvar a=window.performance;window.start=Date.now();a:{var b=window;if(a){var c=a.timing;if(c){var d=c.navigationStart,f=c.responseStart;if(f>d&&f<=window.start){window.start=f;b.wsrt=f-d;break a}}a.now&&(b.wsrt=Mat
# ...

# %%
soup.find('div',class_="BYM4Nd")

# %%
#Tutorials from SentDex, slightlty different in style and approach
import urllib.request

# %%
sauce=urllib.request.urlopen("https://www.screener.in/company/WIPRO/consolidated/").read()

# %%
soup=BeautifulSoup(sauce,'lxml')
for i in soup.find_all('p'):
    print(i.text)
    
#All paragraphs
# Out:
# Wipro is a global information technology (IT), consulting and business process services (BPS) company.
# Pros
# Cons
#
#         Sector:
#
#           IT - Software
#
#
#         Industry:
#
#           Computers - Software - Large
#
#
#
#
#       Consolidated Figures in Rs. Crores
#       /
#
#         View Standalone
#
#
#
#
#       Consolidated Figures in Rs. Crores
#       /
#
#         View Standalone
#
#
#
#
#       Consolidated Figures in Rs. Crores
#       /
#
#         View Standalone
#
#
#
#
#       Consolidated Figures in Rs. Crores
#       /
#
#         View Standalone
#
#
#
#
#       Consolidated Figures in Rs. Crores
#       /
#
#         View Standalone
#
#
# Numbers in percentages
# Stock analysis and screening tool
#
#         Mittal Analytics Private Ltd © 2009–2020
#
#         Made with  in India.
#
# Data provided by C-MOTS Internet Technologies Pvt Ltd
# Terms & Privacy.
#
#         Mittal Analytics Private Ltd © 2009–2021
#
# ...

# %%
soup.find_all('h3')
# Out:
# [<h3>Recent announcements</h3>,
#  <h3>Annual reports</h3>,
#  <h3>Credit ratings</h3>,
#  <h3>Concalls</h3>]

# %%
soup.get_text().strip('\n')##Retrieves all the text on the website
# Out:
# 'Wipro Ltd financial results and price chart - Screener\n\n\n\n\n\n\n(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({\'gtm.start\':\n  new Date().getTime(),event:\'gtm.js\'});var f=d.getElementsByTagName(s)[0],\n  j=d.createElement(s),dl=l!=\'dataLayer\'?\'&l=\'+l:\'\';j.async=true;j.src=\n  \'https://www.googletagmanager.com/gtm.js?id=\'+i+dl;f.parentNode.insertBefore(j,f);\n  })(window,document,\'script\',\'dataLayer\',\'GTM-KG8ZGC4\');\n\n\n\n\n\n\n\n\n\n\n\n  tr[data-row-company-name="Wipro"] {\n    font-weight: 500;\n  }\n\n  tr[data-row-company-name="Wipro"] a {\n    color: var(--ink-900);\n  }\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n          Close\n        \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n          \n          Home\n          \n        \n\n          Screens\n        \n\nTools\n\n\n\n\n\n\n\nCreate a stock screen\nRun queries on 10 years of financial data\n\n\n\n\n\n\nPremium features\n\n\n\n\n\n\n\n\n\nExport / import trade data\nSee price trends of raw materials and finished goods\n\n\n\n
# ...

# %%
text='yahoo finance wipro ltd'
sauce=requests.get("https://www.google.com/search?q="+text).text
soup=BeautifulSoup(sauce,'lxml')

# %%
#ALl links
for i in soup.find_all('a'):
    print(i.get('href'))
    print('---------------------------------------------------------------------------------------')
# Out:
# /?sa=X&ved=0ahUKEwjtj4fs99rwAhW07XMBHeZjAa0QOwgC
# ---------------------------------------------------------------------------------------
# /?output=search&ie=UTF-8&sa=X&ved=0ahUKEwjtj4fs99rwAhW07XMBHeZjAa0QPAgE
# ---------------------------------------------------------------------------------------
# /search?q=yahoo+finance+wipro+ltd&ie=UTF-8&gbv=1&sei=Hr2nYO2IO7Tbz7sP5seF6Ao
# ---------------------------------------------------------------------------------------
# /search?q=yahoo+finance+wipro+ltd&ie=UTF-8&source=lnms&tbm=nws&sa=X&ved=0ahUKEwjtj4fs99rwAhW07XMBHeZjAa0Q_AUICCgB
# ---------------------------------------------------------------------------------------
# /search?q=yahoo+finance+wipro+ltd&ie=UTF-8&source=lnms&tbm=isch&sa=X&ved=0ahUKEwjtj4fs99rwAhW07XMBHeZjAa0Q_AUICSgC
# ---------------------------------------------------------------------------------------
# ...

# %%
#Scrapping table

# %%
sauce=requests.get('https://www.screener.in/company/WIPRO/consolidated/#profit-loss').text
soup=BeautifulSoup(sauce,'lxml')

# %%
for i in soup.table: #soup.find_all('table') is a more sophisticated method
    print(i)
# Out:
# <thead>
# <tr>
# <th class="text"></th>
# <th>Jun 2018</th>
# <th>Sep 2018</th>
# <th>Dec 2018</th>
# <th>Mar 2019</th>
# <th>Jun 2019</th>
# <th>Sep 2019</th>
# <th>Dec 2019</th>
# <th>Mar 2020</th>
# <th>Jun 2020</th>
# <th>Sep 2020</th>
# <th>Dec 2020</th>
# <th>Mar 2021</th>
# </tr>
# </thead>
#
#
# <tbody>
# <tr class="stripe">
# <td class="text">
# <button class="button-plain" onclick="Company.showSchedule('Sales', 'quarters', this)">
#             Sales <span class="blue-icon">+</span>
# </button>
# </td>
# <td>14,231</td>
# <td>14,568</td>
# <td>15,060</td>
# <td>15,161</td>
# <td>14,786</td>
# <td>15,131</td>
# <td>15,470</td>
# <td>15,750</td>
# <td>14,923</td>
# <td>15,097</td>
# <td>15,670</td>
# <td>16,245</td>
# </tr>
# <tr class="">
# <td class="text">
# <button class="button-plain" onclick="Company.showSchedule('Expenses', 'quarters', this)">
#             Expenses <span class="blue-icon">+</span>
# </button>
# </td>
# <td>11,549</td>
# <td>12,191</td>
# ...

# %%
# using Pandas getting dataframe
import pandas as pd
for i in pd.read_html('https://www.screener.in/company/WIPRO/consolidated/#profit-loss'):
    print(i)
# Out:
#            Unnamed: 0 Jun 2018 Sep 2018 Dec 2018 Mar 2019 Jun 2019 Sep 2019  \
# 0             Sales +    14231    14568    15060    15161    14786    15131
# 1          Expenses +    11549    12191    11766    11903    11841    12035
# 2    Operating Profit     2682     2377     3293     3258     2945     3096
# 3               OPM %      19%      16%      22%      21%      20%      20%
# 4        Other Income      597      637      628      754      780      745
# 5            Interest      165      157      163      253      158      225
# 6        Depreciation      434      437      517      559      495      481
# 7   Profit before tax     2680     2420     3241     3200     3072     3134
# 8               Tax %      22%      22%      22%      22%      22%      18%
# 9          Net Profit     2121     1889     2510     2484     2388     2553
# 10          EPS in Rs     3.52     3.13     4.16     4.12     3.96     4.47
# ...

# %%
#Accessing sitemap and all links from it

# %%
sauce=requests.get('https://pythonprogramming.net//sitemap.xml').text

# %%
soup=BeautifulSoup(sauce,'xml')
for i in soup.find_all('loc'):
    print(i.text)
# Out:
# https://pythonprogramming.net/downloads/intraQuarter.zip/
# https://pythonprogramming.net/downloads/knowledgeBase.db
# https://pythonprogramming.net/downloads/key_stats.csv
# https://pythonprogramming.net/downloads/style.zip
# https://pythonprogramming.net/community/post/
# https://pythonprogramming.net/NVIDIA/GameGAN.pdf
# https://pythonprogramming.net/about/privacy-policy/
# https://pythonprogramming.net/store/python-hoodie/
# https://pythonprogramming.net/about/super-powers/
# https://pythonprogramming.net/about/technology/
# https://pythonprogramming.net/about/tos/
# https://pythonprogramming.net/user/change-password/
# https://pythonprogramming.net/go/template-news-aggregator-go-language-programming-tutorial/
# https://pythonprogramming.net/go/looping-sitemap-data-go-language-programming-tutorial/
# https://pythonprogramming.net/go/channel-buffer-range-go-language-programming-tutorial/
# https://pythonprogramming.net/go/concurrency-web-app-go-language-programming-tutorial/
# ...

# %%
## Fun stuff and personal projects

# %%
#access industry list
sauce=requests.get('https://www.screener.in/explore/').text
soup=BeautifulSoup(sauce,'lxml')

# %%
soup.find('div',class_='flex-row flex-gap-12').text.strip()
# Out:
# 'Agro Chemicals\nAir Transport Service\nAlcoholic Beverages\nAuto Ancillaries\nAutomobile\nBanks\nBearings\nCables\nCapital Goods - Electrical Equipment\nCapital Goods-Non Electrical Equipment\nCastings, Forgings & Fastners\nCement\nCement - Products\nCeramic Products\nChemicals\nComputer Education\nConstruction\nConsumer Durables\nCredit Rating Agencies\nCrude Oil & Natural Gas\nDiamond, Gems and Jewellery\nDiversified\nDry cells\nE-Commerce/App based Aggregator\nEdible Oil\nEducation\nElectronics\nEngineering\nEntertainment\nETF\nFerro Alloys\nFertilizers\nFinance\nFMCG\nGas Distribution\nGlass & Glass Products\nHealthcare\nHotels & Restaurants\nInfrastructure Developers & Operators\nInfrastructure Investment Trusts\nInsurance\nIT - Hardware\nIT - Software\nLeather\nLogistics\nMarine Port & Services\nMedia - Print/Television/Radio\nMining & Mineral products\nMiscellaneous\nNon Ferrous Metals\nOil Drill/Allied\nOnline Media\nPackaging\nPaints/Varnish\nPaper\nPetrochemicals\nPharmace
# ...

# %%
for i in soup.find_all('div',class_='flex-row flex-gap-12'):
    print(i.text,end=' link :')
    print(i.get('href'))
# Out:
# Agro Chemicals
# Air Transport Service
# Alcoholic Beverages
# Auto Ancillaries
# Automobile
# Banks
# Bearings
# Cables
# Capital Goods - Electrical Equipment
# Capital Goods-Non Electrical Equipment
# Castings, Forgings & Fastners
# Cement
# Cement - Products
# Ceramic Products
# Chemicals
# Computer Education
# Construction
# Consumer Durables
# Credit Rating Agencies
# Crude Oil & Natural Gas
# Diamond, Gems and Jewellery
# Diversified
# Dry cells
# E-Commerce/App based Aggregator
# Edible Oil
# Education
# Electronics
# Engineering
# Entertainment
# ETF
# Ferro Alloys
# Fertilizers
# Finance
# FMCG
# Gas Distribution
# Glass & Glass Products
# Healthcare
# Hotels & Restaurants
# Infrastructure Developers & Operators
# Infrastructure Investment Trusts
# Insurance
# IT - Hardware
# IT - Software
# Leather
# Logistics
# Marine Port & Services
# Media - Print/Television/Radio
# Mining & Mineral products
# Miscellaneous
# Non Ferrous Metals
# Oil Drill/Allied
# Online Media
# ...

# %%
industry=soup.find('div',class_='flex-row flex-gap-12')
for i in  industry.find_all('a'):
    print(i.text,end=' link: ')
    print('screen.in'+i['href'])
# Out:
# Agro Chemicals link: screen.in/company/compare/00000001/
# Air Transport Service link: screen.in/company/compare/00000002/
# Alcoholic Beverages link: screen.in/company/compare/00000003/
# Auto Ancillaries link: screen.in/company/compare/00000004/
# Automobile link: screen.in/company/compare/00000005/
# Banks link: screen.in/company/compare/00000006/
# Bearings link: screen.in/company/compare/00000066/
# Cables link: screen.in/company/compare/00000007/
# Capital Goods - Electrical Equipment link: screen.in/company/compare/00000008/
# Capital Goods-Non Electrical Equipment link: screen.in/company/compare/00000009/
# Castings, Forgings & Fastners link: screen.in/company/compare/00000010/
# Cement link: screen.in/company/compare/00000011/
# Cement - Products link: screen.in/company/compare/00000012/
# Ceramic Products link: screen.in/company/compare/00000013/
# Chemicals link: screen.in/company/compare/00000014/
# Computer Education link: screen.in/company/compare/00000015/
# ...
